# %%
import pandas as pd

import main

df=pd.DataFrame(main.index)
df
# Out:
#     id                                           geometry     plan_num  \
# 0  1.0  POLYGON ((220201.357 628123.210, 220440.861 62...          999
# 1  2.0  POLYGON ((220388.882 627800.986, 220383.521 62...  101-0657601
# 2  2.0  POLYGON ((220388.882 627800.986, 220383.521 62...  101-0657601
# 3  3.0  POLYGON ((220455.022 627892.088, 220451.318 62...  101-0547992
# 4  4.0  MULTIPOLYGON (((220066.102 627812.709, 220051....  101-0822452
# 5  5.0  POLYGON ((220521.824 627932.975, 220525.940 62...  101-0560805
# 6  6.0  POLYGON ((219979.089 627604.384, 219967.971 62...  101-1103571
# 7  7.0  POLYGON ((220082.056 627554.698, 220042.106 62...        14295
# 8  8.0  POLYGON ((220098.798 627560.850, 220131.302 62...  101-0657593
# 9  9.0  POLYGON ((219856.646 626847.652, 219836.117 62...  101-0657593
#
#                                            plan_name  source  \
# 0                                         חניון נצבא     NaN
# 1                                          שערי ציון     NaN
# ...
