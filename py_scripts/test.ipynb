# %%
import pandas as pd

import geographical_features

df=pd.DataFrame(geographical_features.forecast)
df
# Out:
#                    Name_hebre main_sector classification_name  Shape_Length  \
# Taz_num
# 3008.0             חניון נצבא      Jewish           כללי צעיר   1529.406023
# 3312.0   סטריפ דרך חברון דרום      Jewish           כללי צעיר   2056.390116
# 3311.0             גבעת המטוס      Jewish           כללי צעיר   2263.979987
# 3601.0          בית צפפא מזרח        Arab          ערבי מאוזן   1489.869222
# 3009.0   סטריפ דרך חברון צפון      Jewish           כללי צעיר   1071.062705
# 3007.0     דרך חברון אשר וינר      Jewish           כללי צעיר   1560.865752
#
#             Shape_Area  Student_by_Classrooms  \
# Taz_num
# 3008.0   127367.285166                      0
# 3312.0   129610.690438                      1
# 3311.0   231733.517211                      0
# 3601.0   150074.543659                      0
# 3009.0    67863.168750                      1
# 3007.0    59570.861254                      0
#
#                                                   geometry ENG_NAME_nafa  \
# Taz_num
# ...
